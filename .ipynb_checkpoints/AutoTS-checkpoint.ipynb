# %%
# also load: _hourly, _monthly, _weekly, _yearly, or _live_daily
from autots import AutoTS, load_daily

# sample datasets can be used in either of the long or wide import shapes
long = False
df = load_daily(long=long)

model = AutoTS(
    forecast_length=21,
    frequency='infer',
    prediction_interval=0.9,
    ensemble=None,
    model_list="fast",  # "superfast", "default", "fast_parallel"
    transformer_list="fast",  # "superfast",
    drop_most_recent=1,
    max_generations=4,
    num_validations=2,
    validation_method="backwards"
)
model = model.fit(
    df,
    date_col='datetime' if long else None,
    value_col='value' if long else None,
    id_col='series_id' if long else None,
)

prediction = model.predict()
# plot a sample
prediction.plot(model.df_wide_numeric,
                series=model.df_wide_numeric.columns[0],
                start_date="2019-01-01")
# Print the details of the best model
print(model)

# point forecasts dataframe
forecasts_df = prediction.forecast
# upper and lower forecasts
forecasts_up, forecasts_low = prediction.upper_forecast, prediction.lower_forecast

# accuracy of all tried model results
model_results = model.results()
# and aggregated from cross validation
validation_results = model.results("validation")
# Out:
# Inferred frequency is: D
# Model Number: 1 with model AverageValueNaive in generation 0 of 4
# Model Number: 2 with model AverageValueNaive in generation 0 of 4
# Model Number: 3 with model AverageValueNaive in generation 0 of 4
# Model Number: 4 with model DatepartRegression in generation 0 of 4
# Model Number: 5 with model DatepartRegression in generation 0 of 4
# Model Number: 6 with model DatepartRegression in generation 0 of 4
# C:\Users\yensanwoo\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Model Number: 7 with model DatepartRegression in generation 0 of 4
# Template Eval Error: Exception('Transformer PowerTransformer failed on fit') in model 7: DatepartRegression
# Model Number: 8 with model ETS in generation 0 of 4
# Model Number: 9 with model ETS in generation 0 of 4
# Model Number: 10 with model GLM in generation 0 of 4
# Model Number: 11 with model GLM in generation 0 of 4
# Model Number: 12 with model GLS in generation 0 of 4
# Model Number: 13 with model GLS in generation 0 of 4
# Model Number: 14 with model LastValueNaive in generation 0 of 4
# Template Eval Error: Exception('Transformer PowerTransformer failed on fit') in model 14: LastValueNaive
# Model Number: 15 with model LastValueNaive in generation 0 of 4
# Model Number: 16 with model LastValueNaive in generation 0 of 4
# Model Number: 17 with model LastValueNaive in generation 0 of 4
# Model Number: 18 with model SeasonalNaive in generation 0 of 4
# Template Eval Error: Exception('Transformer PowerTransformer failed on fit') in model 18: SeasonalNaive
# Model Number: 19 with model SeasonalNaive in generation 0 of 4
# Model Number: 20 with model SeasonalNaive in generation 0 of 4
# Model Number: 21 with model VAR in generation 0 of 4
# Model Number: 22 with model VAR in generation 0 of 4
# Model Number: 23 with model VECM in generation 0 of 4
# Template Eval Error: Exception('Transformer PowerTransformer failed on fit') in model 23: VECM
# Model Number: 24 with model VECM in generation 0 of 4
# Model Number: 25 with model WindowRegression in generation 0 of 4
# Model Number: 26 with model ConstantNaive in generation 0 of 4
# Template Eval Error: Exception('Transformer PowerTransformer failed on fit') in model 26: ConstantNaive
# Model Number: 27 with model DatepartRegression in generation 0 of 4
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 27: DatepartRegression
# Model Number: 28 with model SeasonalNaive in generation 0 of 4
# C:\Users\yensanwoo\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Model Number: 29 with model DatepartRegression in generation 0 of 4
# Model Number: 30 with model ETS in generation 0 of 4
# Model Number: 31 with model VECM in generation 0 of 4
# Model Number: 32 with model MultivariateMotif in generation 0 of 4
# Model Number: 33 with model MultivariateMotif in generation 0 of 4
# Model Number: 34 with model UnivariateMotif in generation 0 of 4
# Model Number: 35 with model UnivariateMotif in generation 0 of 4
# Model Number: 36 with model SectionalMotif in generation 0 of 4
# Model Number: 37 with model SectionalMotif in generation 0 of 4
# Model Number: 38 with model SeasonalNaive in generation 0 of 4
# Model Number: 39 with model DatepartRegression in generation 0 of 4
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 11 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 100 out of 100 | elapsed:    0.2s finished
# [Parallel(n_jobs=11)]: Using backend ThreadingBackend with 11 concurrent workers.
# [Parallel(n_jobs=11)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=11)]: Done 100 out of 100 | elapsed:    0.0s finished
# Model Number: 40 with model NVAR in generation 0 of 4
# Template Eval Error: ValueError('Model NVAR returned NaN for one or more series. fail_on_forecast_nan=True') in model 40: NVAR
# Model Number: 41 with model Cassandra in generation 0 of 4
# Model Number: 42 with model ConstantNaive in generation 0 of 4
# Model Number: 43 with model LastValueNaive in generation 0 of 4
# Model Number: 44 with model AverageValueNaive in generation 0 of 4
# Model Number: 45 with model GLS in generation 0 of 4
# Model Number: 46 with model SeasonalNaive in generation 0 of 4
# Model Number: 47 with model GLM in generation 0 of 4
# Template Eval Error: ValueError('regression_type=user and no future_regressor passed') in model 47: GLM
# Model Number: 48 with model ETS in generation 0 of 4
# Model Number: 49 with model VAR in generation 0 of 4
# Template Eval Error: Exception('Transformer PowerTransformer failed on fit') in model 49: VAR
# Model Number: 50 with model VECM in generation 0 of 4
# Model Number: 51 with model WindowRegression in generation 0 of 4
# Template Eval Error: Exception('Transformer PowerTransformer failed on fit') in model 51: WindowRegression
# Model Number: 52 with model DatepartRegression in generation 0 of 4
# Template Eval Error: Exception('Transformer PowerTransformer failed on fit') in model 52: DatepartRegression
# Model Number: 53 with model UnivariateMotif in generation 0 of 4
# Model Number: 54 with model MultivariateMotif in generation 0 of 4
# Model Number: 55 with model SectionalMotif in generation 0 of 4
# Model Number: 56 with model NVAR in generation 0 of 4
# Model Number: 57 with model MAR in generation 0 of 4
# Template Eval Error: ValueError('Shape of passed values is (14, 21), indices imply (21, 21)') in model 57: MAR
# Model Number: 58 with model RRVAR in generation 0 of 4
# Model Number: 59 with model KalmanStateSpace in generation 0 of 4
# Model Number: 60 with model MetricMotif in generation 0 of 4
# Model Number: 61 with model Cassandra in generation 0 of 4
# Model Number: 62 with model SeasonalityMotif in generation 0 of 4
# Model Number: 63 with model MetricMotif in generation 0 of 4
# Model Number: 64 with model ETS in generation 0 of 4
# Template Eval Error: Exception('Transformer DatepartRegression failed on fit') in model 64: ETS
# Model Number: 65 with model VECM in generation 0 of 4
# Model Number: 66 with model MAR in generation 0 of 4
# Template Eval Error: ValueError('Shape of passed values is (7, 21), indices imply (21, 21)') in model 66: MAR
# Model Number: 67 with model GLS in generation 0 of 4
# Model Number: 68 with model MAR in generation 0 of 4
# Model Number: 69 with model ETS in generation 0 of 4
# Model Number: 70 with model VECM in generation 0 of 4
# Model Number: 71 with model SectionalMotif in generation 0 of 4
# Model Number: 72 with model ETS in generation 0 of 4
# Model Number: 73 with model SeasonalNaive in generation 0 of 4
# Template Eval Error: Exception('Transformer PowerTransformer failed on fit') in model 73: SeasonalNaive
# Model Number: 74 with model SeasonalNaive in generation 0 of 4
# Model Number: 75 with model SeasonalNaive in generation 0 of 4
# Model Number: 76 with model MultivariateMotif in generation 0 of 4
# Model Number: 77 with model RRVAR in generation 0 of 4
# Model Number: 78 with model SeasonalNaive in generation 0 of 4
# Model Number: 79 with model ConstantNaive in generation 0 of 4
# Model Number: 80 with model RRVAR in generation 0 of 4
# Model Number: 81 with model UnivariateMotif in generation 0 of 4
# Template Eval Error: ValueError('Model UnivariateMotif returned NaN for one or more series. fail_on_forecast_nan=True') in model 81: UnivariateMotif
# Model Number: 82 with model MultivariateMotif in generation 0 of 4
# Model Number: 83 with model Cassandra in generation 0 of 4
# C:\Users\yensanwoo\anaconda3\lib\site-packages\numpy\lib\function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\yensanwoo\anaconda3\lib\site-packages\numpy\lib\function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Model Number: 84 with model SectionalMotif in generation 0 of 4
# Model Number: 85 with model VAR in generation 0 of 4
# Model Number: 86 with model MetricMotif in generation 0 of 4
# Model Number: 87 with model WindowRegression in generation 0 of 4
# Template Eval Error: ModuleNotFoundError("No module named 'lightgbm'") in model 87: WindowRegression
# Model Number: 88 with model ETS in generation 0 of 4
# Model Number: 89 with model WindowRegression in generation 0 of 4
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 89: WindowRegression
# Model Number: 90 with model NVAR in generation 0 of 4
# Model Number: 91 with model MetricMotif in generation 0 of 4
# Model Number: 92 with model MetricMotif in generation 0 of 4
# Model Number: 93 with model ConstantNaive in generation 0 of 4
# Model Number: 94 with model ConstantNaive in generation 0 of 4
# Model Number: 95 with model UnivariateMotif in generation 0 of 4
# Model Number: 96 with model LastValueNaive in generation 0 of 4
# Model Number: 97 with model LastValueNaive in generation 0 of 4
# Model Number: 98 with model RRVAR in generation 0 of 4
# Model Number: 99 with model VAR in generation 0 of 4
# Model Number: 100 with model VAR in generation 0 of 4
# Model Number: 101 with model MAR in generation 0 of 4
# Template Eval Error: ValueError('Shape of passed values is (14, 21), indices imply (21, 21)') in model 101: MAR
# Model Number: 102 with model LastValueNaive in generation 0 of 4
# Model Number: 103 with model ETS in generation 0 of 4
# Model Number: 104 with model VECM in generation 0 of 4
# Template Eval Error: Exception('Transformer PowerTransformer failed on fit') in model 104: VECM
# Model Number: 105 with model Cassandra in generation 0 of 4
# Model Number: 106 with model UnivariateMotif in generation 0 of 4
# Model Number: 107 with model MetricMotif in generation 0 of 4
# Model Number: 108 with model AverageValueNaive in generation 0 of 4
# Model Number: 109 with model VAR in generation 0 of 4
# C:\Users\yensanwoo\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.92128e-26): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# Model Number: 110 with model RRVAR in generation 0 of 4
# Model Number: 111 with model WindowRegression in generation 0 of 4
# Template Eval Error: ModuleNotFoundError("No module named 'lightgbm'") in model 111: WindowRegression
# Model Number: 112 with model VECM in generation 0 of 4
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 112: VECM
# Model Number: 113 with model AverageValueNaive in generation 0 of 4
# Model Number: 114 with model ConstantNaive in generation 0 of 4
# Template Eval Error: Exception('Transformer PowerTransformer failed on fit') in model 114: ConstantNaive
# Model Number: 115 with model SeasonalityMotif in generation 0 of 4
# Template Eval Error: Exception('Transformer PowerTransformer failed on fit') in model 115: SeasonalityMotif
# Model Number: 116 with model SeasonalityMotif in generation 0 of 4
# Model Number: 117 with model ETS in generation 0 of 4
# C:\Users\yensanwoo\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.92128e-26): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# Model Number: 118 with model LastValueNaive in generation 0 of 4
# Model Number: 119 with model NVAR in generation 0 of 4
# Template Eval Error: ValueError('Model NVAR returned NaN for one or more series. fail_on_forecast_nan=True') in model 119: NVAR
# Model Number: 120 with model LastValueNaive in generation 0 of 4
# Model Number: 121 with model AverageValueNaive in generation 0 of 4
# Model Number: 122 with model ETS in generation 0 of 4
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 122: ETS
# Model Number: 123 with model SectionalMotif in generation 0 of 4
# Model Number: 124 with model UnivariateMotif in generation 0 of 4
# Model Number: 125 with model SeasonalityMotif in generation 0 of 4
# Model Number: 126 with model LastValueNaive in generation 0 of 4
# Template Eval Error: ValueError("Model returned NaN due to a preprocessing transformer {'fillna': 'ffill', 'transformations': {'0': 'ClipOutliers', '1': 'Detrend', '2': 'SeasonalDifference', '3': 'AlignLastValue'}, 'transformation_params': {'0': {'method': 'clip', 'std_threshold': 4, 'fillna': None}, '1': {'model': 'GLS', 'phi': 1, 'window': None, 'transform_dict': {'fillna': None, 'transformations': {'0': 'ClipOutliers'}, 'transformation_params': {'0': {'method': 'clip', 'std_threshold': 3}}}}, '2': {'lag_1': 7, 'method': 'LastValue'}, '3': {'rows': 1, 'lag': 28, 'method': 'multiplicative', 'strength': 1.0, 'first_value_only': False}}}. fail_on_forecast_nan=True") in model 126: LastValueNaive
# Model Number: 127 with model SectionalMotif in generation 0 of 4
# Model Number: 128 with model ConstantNaive in generation 0 of 4
# Model Number: 129 with model Cassandra in generation 0 of 4
# Model Number: 130 with model MetricMotif in generation 0 of 4
# Model Number: 131 with model AverageValueNaive in generation 0 of 4
# Model Number: 132 with model SectionalMotif in generation 0 of 4
# Template Eval Error: Exception('Transformer PowerTransformer failed on fit') in model 132: SectionalMotif
# Model Number: 133 with model MetricMotif in generation 0 of 4
# Model Number: 134 with model WindowRegression in generation 0 of 4
# Model Number: 135 with model MetricMotif in generation 0 of 4
# Model Number: 136 with model SectionalMotif in generation 0 of 4
# Model Number: 137 with model SeasonalityMotif in generation 0 of 4
# Model Number: 138 with model VECM in generation 0 of 4
# Model Number: 139 with model NVAR in generation 0 of 4
# Template Eval Error: ValueError('Model NVAR returned NaN for one or more series. fail_on_forecast_nan=True') in model 139: NVAR
# Model Number: 140 with model Cassandra in generation 0 of 4
# Model Number: 141 with model VECM in generation 0 of 4
# Template Eval Error: Exception('Transformer PowerTransformer failed on fit') in model 141: VECM
# Model Number: 142 with model NVAR in generation 0 of 4
# Model Number: 143 with model KalmanStateSpace in generation 0 of 4
# Model Number: 144 with model DatepartRegression in generation 0 of 4
# Epoch 1/50
# 46/46 [==============================] - 5s 23ms/step - loss: 3559288.2500 - val_loss: 34787.1875
# Epoch 2/50
# 46/46 [==============================] - 1s 13ms/step - loss: 5676023.0000 - val_loss: 33576.0156
# Epoch 3/50
# 46/46 [==============================] - 1s 15ms/step - loss: 9421993.0000 - val_loss: 28838.1250
# Epoch 4/50
# 46/46 [==============================] - 1s 12ms/step - loss: 7714590.0000 - val_loss: 44333.0469
# Epoch 5/50
# 46/46 [==============================] - 1s 14ms/step - loss: 7466162.0000 - val_loss: 26702.8926
# Epoch 6/50
# 46/46 [==============================] - 1s 15ms/step - loss: 4062880.5000 - val_loss: 25736.3164
# Epoch 7/50
# 46/46 [==============================] - 1s 13ms/step - loss: 6883160.5000 - val_loss: 27936.4980
# Epoch 8/50
# 46/46 [==============================] - 1s 14ms/step - loss: 8591054.0000 - val_loss: 21188.1387
# Epoch 9/50
# 46/46 [==============================] - 1s 13ms/step - loss: 7694447.0000 - val_loss: 28896.5215
# Epoch 10/50
# 46/46 [==============================] - 1s 13ms/step - loss: 5229418.0000 - val_loss: 22742.9062
# Epoch 11/50
# 46/46 [==============================] - 1s 13ms/step - loss: 5458010.0000 - val_loss: 21023.7910
# Epoch 12/50
# 46/46 [==============================] - 1s 12ms/step - loss: 7521932.0000 - val_loss: 39823.8711
# Epoch 13/50
# 46/46 [==============================] - 0s 11ms/step - loss: 7383494.5000 - val_loss: 19867.7266
# Epoch 14/50
# 46/46 [==============================] - 1s 11ms/step - loss: 7940753.0000 - val_loss: 31576.0410
# Epoch 15/50
# 46/46 [==============================] - 1s 14ms/step - loss: 5874508.5000 - val_loss: 26708.9395
# Epoch 16/50
# 46/46 [==============================] - 1s 14ms/step - loss: 5651488.0000 - val_loss: 24528.7617
# Epoch 17/50
# 46/46 [==============================] - 1s 17ms/step - loss: 3531203.0000 - val_loss: 41781.8008
# Epoch 18/50
# 46/46 [==============================] - 1s 17ms/step - loss: 8946177.0000 - val_loss: 35189.6641
# Epoch 19/50
# 46/46 [==============================] - 1s 18ms/step - loss: 10941756.0000 - val_loss: 28183.7832
# Epoch 20/50
# 46/46 [==============================] - 1s 20ms/step - loss: 4113096.0000 - val_loss: 27821.2070
# Epoch 21/50
# 46/46 [==============================] - 1s 16ms/step - loss: 12445438.0000 - val_loss: 29964.0996
# Epoch 22/50
# 46/46 [==============================] - 1s 15ms/step - loss: 8025701.0000 - val_loss: 26786.7090
# Epoch 23/50
# 46/46 [==============================] - 1s 17ms/step - loss: 5130316.5000 - val_loss: 35024.0508
# 1/1 [==============================] - 0s 468ms/step
# Template Eval Error: ValueError('Model DatepartRegression returned NaN for one or more series. fail_on_forecast_nan=True') in model 144: DatepartRegression
# Model Number: 145 with model ETS in generation 0 of 4
# Model Number: 146 with model NVAR in generation 0 of 4
# New Generation: 1 of 4
# Model Number: 147 with model SectionalMotif in generation 1 of 4
# Model Number: 148 with model MultivariateMotif in generation 1 of 4
# Model Number: 149 with model MultivariateMotif in generation 1 of 4
# Model Number: 150 with model MultivariateMotif in generation 1 of 4
# Model Number: 151 with model LastValueNaive in generation 1 of 4
# Model Number: 152 with model SeasonalNaive in generation 1 of 4
# Model Number: 153 with model ConstantNaive in generation 1 of 4
# Model Number: 154 with model SeasonalNaive in generation 1 of 4
# Model Number: 155 with model MetricMotif in generation 1 of 4
# Model Number: 156 with model LastValueNaive in generation 1 of 4
# Model Number: 157 with model UnivariateMotif in generation 1 of 4
# Model Number: 158 with model UnivariateMotif in generation 1 of 4
# Template Eval Error: Exception('Transformer PowerTransformer failed on fit') in model 158: UnivariateMotif
# Model Number: 159 with model MultivariateMotif in generation 1 of 4
# Model Number: 160 with model Cassandra in generation 1 of 4
# Model Number: 161 with model MultivariateMotif in generation 1 of 4
# Model Number: 162 with model GLM in generation 1 of 4
# Model Number: 163 with model VAR in generation 1 of 4
# Model Number: 164 with model NVAR in generation 1 of 4
# Model Number: 165 with model VECM in generation 1 of 4
# Model Number: 166 with model KalmanStateSpace in generation 1 of 4
# Model Number: 167 with model LastValueNaive in generation 1 of 4
# Model Number: 168 with model AverageValueNaive in generation 1 of 4
# Model Number: 169 with model VECM in generation 1 of 4
# Model Number: 170 with model GLS in generation 1 of 4
# C:\Users\yensanwoo\anaconda3\lib\site-packages\autots\models\basics.py:2100: RuntimeWarning: invalid value encountered in sqrt
#   df_stdev = np.sqrt(result.observations.cov).T
# Model Number: 171 with model GLS in generation 1 of 4
# Model Number: 172 with model ETS in generation 1 of 4
# Model Number: 173 with model SeasonalNaive in generation 1 of 4
# Model Number: 174 with model VECM in generation 1 of 4
# Template Eval Error: LinAlgError('Singular matrix') in model 174: VECM
# Model Number: 175 with model GLM in generation 1 of 4
# Model Number: 176 with model DatepartRegression in generation 1 of 4
# Model Number: 177 with model SeasonalNaive in generation 1 of 4
# Model Number: 178 with model MAR in generation 1 of 4
# HolidayTransformer: no anomalies detected.
# Template Eval Error: ValueError('Shape of passed values is (7, 21), indices imply (21, 21)') in model 178: MAR
# Model Number: 179 with model MetricMotif in generation 1 of 4
# Model Number: 180 with model AverageValueNaive in generation 1 of 4
# Model Number: 181 with model VECM in generation 1 of 4
# Model Number: 182 with model NVAR in generation 1 of 4
# Template Eval Error: ValueError('Model NVAR returned NaN for one or more series. fail_on_forecast_nan=True') in model 182: NVAR
# Model Number: 183 with model WindowRegression in generation 1 of 4
# Model Number: 184 with model SeasonalNaive in generation 1 of 4
# C:\Users\yensanwoo\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Model Number: 185 with model VECM in generation 1 of 4
# Model Number: 186 with model Cassandra in generation 1 of 4
# Model Number: 187 with model VECM in generation 1 of 4
# Template Eval Error: Exception('Transformer PowerTransformer failed on fit') in model 187: VECM
# Model Number: 188 with model ConstantNaive in generation 1 of 4
# Model Number: 189 with model SeasonalNaive in generation 1 of 4
# Model Number: 190 with model SeasonalityMotif in generation 1 of 4
# Model Number: 191 with model Cassandra in generation 1 of 4
# Model Number: 192 with model MultivariateMotif in generation 1 of 4
# Model Number: 193 with model VECM in generation 1 of 4
# Model Number: 194 with model SectionalMotif in generation 1 of 4
# Model Number: 195 with model SectionalMotif in generation 1 of 4
# Model Number: 196 with model VAR in generation 1 of 4
# Template Eval Error: IndexError('tuple index out of range') in model 196: VAR
# Model Number: 197 with model SeasonalNaive in generation 1 of 4
# Model Number: 198 with model SectionalMotif in generation 1 of 4
# Model Number: 199 with model VECM in generation 1 of 4
# Model Number: 200 with model AverageValueNaive in generation 1 of 4
# Model Number: 201 with model ETS in generation 1 of 4
# Model Number: 202 with model SeasonalityMotif in generation 1 of 4
# Model Number: 203 with model RRVAR in generation 1 of 4
# Model Number: 204 with model DatepartRegression in generation 1 of 4
# Model Number: 205 with model WindowRegression in generation 1 of 4
# Template Eval Error: ModuleNotFoundError("No module named 'xgboost'") in model 205: WindowRegression
# Model Number: 206 with model SectionalMotif in generation 1 of 4
# Model Number: 207 with model VAR in generation 1 of 4
# Model Number: 208 with model SeasonalityMotif in generation 1 of 4
# Model Number: 209 with model Cassandra in generation 1 of 4
# Model Number: 210 with model AverageValueNaive in generation 1 of 4
# Model Number: 211 with model SectionalMotif in generation 1 of 4
# Model Number: 212 with model VAR in generation 1 of 4
# Model Number: 213 with model UnivariateMotif in generation 1 of 4
# Model Number: 214 with model LastValueNaive in generation 1 of 4
# Model Number: 215 with model ETS in generation 1 of 4
# Model Number: 216 with model RRVAR in generation 1 of 4
# Model Number: 217 with model SeasonalNaive in generation 1 of 4
# Model Number: 218 with model LastValueNaive in generation 1 of 4
# Model Number: 219 with model SeasonalityMotif in generation 1 of 4
# Model Number: 220 with model MetricMotif in generation 1 of 4
# Model Number: 221 with model Cassandra in generation 1 of 4
# Model Number: 222 with model SectionalMotif in generation 1 of 4
# Model Number: 223 with model Cassandra in generation 1 of 4
# Model Number: 224 with model Cassandra in generation 1 of 4
# Model Number: 225 with model SeasonalityMotif in generation 1 of 4
# Model Number: 226 with model MetricMotif in generation 1 of 4
# Model Number: 227 with model MultivariateMotif in generation 1 of 4
# Model Number: 228 with model MetricMotif in generation 1 of 4
# Model Number: 229 with model ETS in generation 1 of 4
# Model Number: 230 with model AverageValueNaive in generation 1 of 4
# Model Number: 231 with model UnivariateMotif in generation 1 of 4
# Model Number: 232 with model SectionalMotif in generation 1 of 4
# Model Number: 233 with model LastValueNaive in generation 1 of 4
# Model Number: 234 with model MetricMotif in generation 1 of 4
# Model Number: 235 with model SectionalMotif in generation 1 of 4
# Model Number: 236 with model UnivariateMotif in generation 1 of 4
# Model Number: 237 with model LastValueNaive in generation 1 of 4
# Model Number: 238 with model VAR in generation 1 of 4
# Model Number: 239 with model VECM in generation 1 of 4
# Model Number: 240 with model MetricMotif in generation 1 of 4
# Template Eval Error: TypeError("'NoneType' object is not subscriptable") in model 240: MetricMotif
# Model Number: 241 with model UnivariateMotif in generation 1 of 4
# Model Number: 242 with model GLM in generation 1 of 4
# Model Number: 243 with model AverageValueNaive in generation 1 of 4
# Model Number: 244 with model SeasonalNaive in generation 1 of 4
# Model Number: 245 with model Cassandra in generation 1 of 4
# Model Number: 246 with model LastValueNaive in generation 1 of 4
# Model Number: 247 with model SectionalMotif in generation 1 of 4
# Model Number: 248 with model MetricMotif in generation 1 of 4
# Model Number: 249 with model ETS in generation 1 of 4
# Model Number: 250 with model ETS in generation 1 of 4
# Model Number: 251 with model VECM in generation 1 of 4
# New Generation: 2 of 4
# Model Number: 252 with model VECM in generation 2 of 4
# Model Number: 253 with model ETS in generation 2 of 4
# Model Number: 254 with model KalmanStateSpace in generation 2 of 4
# Model Number: 255 with model NVAR in generation 2 of 4
# Template Eval Error: ValueError('Model NVAR returned NaN for one or more series. fail_on_forecast_nan=True') in model 255: NVAR
# Model Number: 256 with model UnivariateMotif in generation 2 of 4
# Model Number: 257 with model Cassandra in generation 2 of 4
# Model Number: 258 with model VECM in generation 2 of 4
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 258: VECM
# Model Number: 259 with model ETS in generation 2 of 4
# Model Number: 260 with model SectionalMotif in generation 2 of 4
# Model Number: 261 with model ConstantNaive in generation 2 of 4
# Model Number: 262 with model VECM in generation 2 of 4
# Model Number: 263 with model VECM in generation 2 of 4
# Model Number: 264 with model VECM in generation 2 of 4
# Model Number: 265 with model VAR in generation 2 of 4
# Model Number: 266 with model Cassandra in generation 2 of 4
# Model Number: 267 with model UnivariateMotif in generation 2 of 4
# Model Number: 268 with model UnivariateMotif in generation 2 of 4
# Model Number: 269 with model UnivariateMotif in generation 2 of 4
# Model Number: 270 with model UnivariateMotif in generation 2 of 4
# Model Number: 271 with model MetricMotif in generation 2 of 4
# Model Number: 272 with model SeasonalNaive in generation 2 of 4
# Model Number: 273 with model DatepartRegression in generation 2 of 4
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 273: DatepartRegression
# Model Number: 274 with model GLM in generation 2 of 4
# Template Eval Error: ValueError('NaN, inf or invalid value detected in weights, estimation infeasible.') in model 274: GLM
# Model Number: 275 with model UnivariateMotif in generation 2 of 4
# Model Number: 276 with model SectionalMotif in generation 2 of 4
# Model Number: 277 with model UnivariateMotif in generation 2 of 4
# Model Number: 278 with model SeasonalNaive in generation 2 of 4
# Model Number: 279 with model LastValueNaive in generation 2 of 4
# Model Number: 280 with model SeasonalityMotif in generation 2 of 4
# Model Number: 281 with model SeasonalNaive in generation 2 of 4
# Model Number: 282 with model ConstantNaive in generation 2 of 4
# Model Number: 283 with model VECM in generation 2 of 4
# Model Number: 284 with model SeasonalityMotif in generation 2 of 4
# Model Number: 285 with model LastValueNaive in generation 2 of 4
# Model Number: 286 with model AverageValueNaive in generation 2 of 4
# Model Number: 287 with model LastValueNaive in generation 2 of 4
# Model Number: 288 with model Cassandra in generation 2 of 4
# Model Number: 289 with model AverageValueNaive in generation 2 of 4
# Model Number: 290 with model GLS in generation 2 of 4
# Model Number: 291 with model AverageValueNaive in generation 2 of 4
# Model Number: 292 with model MultivariateMotif in generation 2 of 4
# Model Number: 293 with model VECM in generation 2 of 4
# Model Number: 294 with model ETS in generation 2 of 4
# Model Number: 295 with model WindowRegression in generation 2 of 4
# Model Number: 296 with model SectionalMotif in generation 2 of 4
# Model Number: 297 with model MetricMotif in generation 2 of 4
# Model Number: 298 with model MetricMotif in generation 2 of 4
# Model Number: 299 with model SeasonalNaive in generation 2 of 4
# C:\Users\yensanwoo\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Model Number: 300 with model VAR in generation 2 of 4
# Model Number: 301 with model Cassandra in generation 2 of 4
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 301: Cassandra
# Model Number: 302 with model SectionalMotif in generation 2 of 4
# Model Number: 303 with model RRVAR in generation 2 of 4
# Model Number: 304 with model LastValueNaive in generation 2 of 4
# Model Number: 305 with model MetricMotif in generation 2 of 4
# Model Number: 306 with model LastValueNaive in generation 2 of 4
# Model Number: 307 with model MultivariateMotif in generation 2 of 4
# Model Number: 308 with model RRVAR in generation 2 of 4
# Model Number: 309 with model WindowRegression in generation 2 of 4
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 309: WindowRegression
# Model Number: 310 with model SectionalMotif in generation 2 of 4
# Model Number: 311 with model Cassandra in generation 2 of 4
# Model Number: 312 with model LastValueNaive in generation 2 of 4
# Model Number: 313 with model AverageValueNaive in generation 2 of 4
# Model Number: 314 with model AverageValueNaive in generation 2 of 4
# Model Number: 315 with model KalmanStateSpace in generation 2 of 4
# Model Number: 316 with model SeasonalNaive in generation 2 of 4
# Model Number: 317 with model LastValueNaive in generation 2 of 4
# Model Number: 318 with model SeasonalNaive in generation 2 of 4
# Model Number: 319 with model MultivariateMotif in generation 2 of 4
# Model Number: 320 with model LastValueNaive in generation 2 of 4
# Model Number: 321 with model Cassandra in generation 2 of 4
# Model Number: 322 with model AverageValueNaive in generation 2 of 4
# Model Number: 323 with model Cassandra in generation 2 of 4
# Model Number: 324 with model VAR in generation 2 of 4
# Model Number: 325 with model MultivariateMotif in generation 2 of 4
# Model Number: 326 with model Cassandra in generation 2 of 4
# Model Number: 327 with model SeasonalityMotif in generation 2 of 4
# Model Number: 328 with model MAR in generation 2 of 4
# Model Number: 329 with model NVAR in generation 2 of 4
# Template Eval Error: ValueError('Model NVAR returned NaN for one or more series. fail_on_forecast_nan=True') in model 329: NVAR
# Model Number: 330 with model AverageValueNaive in generation 2 of 4
# Model Number: 331 with model RRVAR in generation 2 of 4
# Model Number: 332 with model SeasonalityMotif in generation 2 of 4
# Model Number: 333 with model KalmanStateSpace in generation 2 of 4
# Model Number: 334 with model VECM in generation 2 of 4
# Model Number: 335 with model Cassandra in generation 2 of 4
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 335: Cassandra
# Model Number: 336 with model SectionalMotif in generation 2 of 4
# Model Number: 337 with model VAR in generation 2 of 4
# Model Number: 338 with model NVAR in generation 2 of 4
# Template Eval Error: ValueError('Model NVAR returned NaN for one or more series. fail_on_forecast_nan=True') in model 338: NVAR
# Model Number: 339 with model Cassandra in generation 2 of 4
# Model Number: 340 with model ETS in generation 2 of 4
# C:\Users\yensanwoo\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.92128e-26): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# Model Number: 341 with model LastValueNaive in generation 2 of 4
# Model Number: 342 with model KalmanStateSpace in generation 2 of 4
# Template Eval Error: Exception('Transformer PowerTransformer failed on fit') in model 342: KalmanStateSpace
# Model Number: 343 with model ETS in generation 2 of 4
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 343: ETS
# Model Number: 344 with model RRVAR in generation 2 of 4
# Model Number: 345 with model MetricMotif in generation 2 of 4
# Model Number: 346 with model SeasonalityMotif in generation 2 of 4
# Model Number: 347 with model MultivariateMotif in generation 2 of 4
# Model Number: 348 with model UnivariateMotif in generation 2 of 4
# Model Number: 349 with model SectionalMotif in generation 2 of 4
# Model Number: 350 with model GLS in generation 2 of 4
# Model Number: 351 with model WindowRegression in generation 2 of 4
# Model Number: 352 with model VECM in generation 2 of 4
# C:\Users\yensanwoo\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Model Number: 353 with model SeasonalNaive in generation 2 of 4
# Model Number: 354 with model ETS in generation 2 of 4
# Model Number: 355 with model LastValueNaive in generation 2 of 4
# Model Number: 356 with model ConstantNaive in generation 2 of 4
# New Generation: 3 of 4
# Model Number: 357 with model VECM in generation 3 of 4
# Model Number: 358 with model MetricMotif in generation 3 of 4
# Model Number: 359 with model NVAR in generation 3 of 4
# Template Eval Error: ValueError('Model NVAR returned NaN for one or more series. fail_on_forecast_nan=True') in model 359: NVAR
# Model Number: 360 with model SeasonalNaive in generation 3 of 4
# Model Number: 361 with model VAR in generation 3 of 4
# Model Number: 362 with model MultivariateMotif in generation 3 of 4
# Model Number: 363 with model MultivariateMotif in generation 3 of 4
# Model Number: 364 with model SeasonalityMotif in generation 3 of 4
# Model Number: 365 with model SectionalMotif in generation 3 of 4
# Model Number: 366 with model VECM in generation 3 of 4
# Model Number: 367 with model SeasonalNaive in generation 3 of 4
# Model Number: 368 with model AverageValueNaive in generation 3 of 4
# Model Number: 369 with model LastValueNaive in generation 3 of 4
# Model Number: 370 with model SeasonalNaive in generation 3 of 4
# Model Number: 371 with model ConstantNaive in generation 3 of 4
# Template Eval Error: Exception('Transformer PowerTransformer failed on fit') in model 371: ConstantNaive
# Model Number: 372 with model UnivariateMotif in generation 3 of 4
# Model Number: 373 with model LastValueNaive in generation 3 of 4
# Model Number: 374 with model SeasonalNaive in generation 3 of 4
# Model Number: 375 with model DatepartRegression in generation 3 of 4
# Template Eval Error: Exception('Transformer PowerTransformer failed on fit') in model 375: DatepartRegression
# Model Number: 376 with model VAR in generation 3 of 4
# Model Number: 377 with model LastValueNaive in generation 3 of 4
# Model Number: 378 with model ETS in generation 3 of 4
# Model Number: 379 with model KalmanStateSpace in generation 3 of 4
# Model Number: 380 with model ETS in generation 3 of 4
# Model Number: 381 with model SeasonalityMotif in generation 3 of 4
# Model Number: 382 with model Cassandra in generation 3 of 4
# C:\Users\yensanwoo\anaconda3\lib\site-packages\numpy\lib\function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\yensanwoo\anaconda3\lib\site-packages\numpy\lib\function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Model Number: 383 with model NVAR in generation 3 of 4
# Model Number: 384 with model SeasonalityMotif in generation 3 of 4
# Model Number: 385 with model WindowRegression in generation 3 of 4
# Model Number: 386 with model GLS in generation 3 of 4
# Model Number: 387 with model ETS in generation 3 of 4
# C:\Users\yensanwoo\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.92128e-26): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# Model Number: 388 with model RRVAR in generation 3 of 4
# Model Number: 389 with model MetricMotif in generation 3 of 4
# Model Number: 390 with model WindowRegression in generation 3 of 4
# Template Eval Error: KeyError('model') in model 390: WindowRegression
# Model Number: 391 with model ETS in generation 3 of 4
# Model Number: 392 with model MetricMotif in generation 3 of 4
# Model Number: 393 with model GLM in generation 3 of 4
# Template Eval Error: ValueError('NaN, inf or invalid value detected in weights, estimation infeasible.') in model 393: GLM
# Model Number: 394 with model UnivariateMotif in generation 3 of 4
# Model Number: 395 with model UnivariateMotif in generation 3 of 4
# Model Number: 396 with model ETS in generation 3 of 4
# Model Number: 397 with model LastValueNaive in generation 3 of 4
# Model Number: 398 with model ConstantNaive in generation 3 of 4
# Model Number: 399 with model MAR in generation 3 of 4
# Template Eval Error: ValueError('Shape of passed values is (7, 21), indices imply (21, 21)') in model 399: MAR
# Model Number: 400 with model SectionalMotif in generation 3 of 4
# Model Number: 401 with model MultivariateMotif in generation 3 of 4
# Model Number: 402 with model ConstantNaive in generation 3 of 4
# Model Number: 403 with model ConstantNaive in generation 3 of 4
# Model Number: 404 with model MetricMotif in generation 3 of 4
# Model Number: 405 with model SeasonalNaive in generation 3 of 4
# Model Number: 406 with model MetricMotif in generation 3 of 4
# Model Number: 407 with model SeasonalityMotif in generation 3 of 4
# Model Number: 408 with model AverageValueNaive in generation 3 of 4
# Model Number: 409 with model Cassandra in generation 3 of 4
# Model Number: 410 with model RRVAR in generation 3 of 4
# Model Number: 411 with model SeasonalNaive in generation 3 of 4
# Model Number: 412 with model UnivariateMotif in generation 3 of 4
# Model Number: 413 with model VECM in generation 3 of 4
# Model Number: 414 with model SeasonalityMotif in generation 3 of 4
# Model Number: 415 with model LastValueNaive in generation 3 of 4
# Model Number: 416 with model UnivariateMotif in generation 3 of 4
# Model Number: 417 with model UnivariateMotif in generation 3 of 4
# Model Number: 418 with model MultivariateMotif in generation 3 of 4
# Model Number: 419 with model SeasonalityMotif in generation 3 of 4
# Model Number: 420 with model AverageValueNaive in generation 3 of 4
# Model Number: 421 with model MultivariateMotif in generation 3 of 4
# Model Number: 422 with model ConstantNaive in generation 3 of 4
# Model Number: 423 with model DatepartRegression in generation 3 of 4
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 423: DatepartRegression
# Model Number: 424 with model WindowRegression in generation 3 of 4
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 424: WindowRegression
# Model Number: 425 with model Cassandra in generation 3 of 4
# Template Eval Error: AttributeError("'NoneType' object has no attribute 'scores'") in model 425: Cassandra
# Model Number: 426 with model SeasonalityMotif in generation 3 of 4
# Model Number: 427 with model NVAR in generation 3 of 4
# Model Number: 428 with model AverageValueNaive in generation 3 of 4
# Model Number: 429 with model SectionalMotif in generation 3 of 4
# Model Number: 430 with model MultivariateMotif in generation 3 of 4
# Model Number: 431 with model VAR in generation 3 of 4
# Model Number: 432 with model Cassandra in generation 3 of 4
# Model Number: 433 with model SectionalMotif in generation 3 of 4
# Model Number: 434 with model WindowRegression in generation 3 of 4
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 434: WindowRegression
# Model Number: 435 with model VECM in generation 3 of 4
# Model Number: 436 with model ETS in generation 3 of 4
# Model Number: 437 with model VECM in generation 3 of 4
# Model Number: 438 with model WindowRegression in generation 3 of 4
# Model Number: 439 with model LastValueNaive in generation 3 of 4
# C:\Users\yensanwoo\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Model Number: 440 with model MultivariateMotif in generation 3 of 4
# Model Number: 441 with model AverageValueNaive in generation 3 of 4
# Model Number: 442 with model ConstantNaive in generation 3 of 4
# Model Number: 443 with model SeasonalNaive in generation 3 of 4
# Model Number: 444 with model SeasonalityMotif in generation 3 of 4
# Model Number: 445 with model ETS in generation 3 of 4
# C:\Users\yensanwoo\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.92128e-26): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# Model Number: 446 with model UnivariateMotif in generation 3 of 4
# Model Number: 447 with model DatepartRegression in generation 3 of 4
# Template Eval Error: ValueError('Model DatepartRegression returned NaN for one or more series. fail_on_forecast_nan=True') in model 447: DatepartRegression
# Model Number: 448 with model LastValueNaive in generation 3 of 4
# C:\Users\yensanwoo\anaconda3\lib\site-packages\sklearn\neighbors\_regression.py:470: UserWarning: One or more samples have no neighbors within specified radius; predicting NaN.
#   warnings.warn(empty_warning_msg)
# Model Number: 449 with model MAR in generation 3 of 4
# Model Number: 450 with model VECM in generation 3 of 4
# Model Number: 451 with model Cassandra in generation 3 of 4
# C:\Users\yensanwoo\anaconda3\lib\site-packages\numpy\lib\function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\yensanwoo\anaconda3\lib\site-packages\numpy\lib\function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Model Number: 452 with model GLS in generation 3 of 4
# Model Number: 453 with model SeasonalityMotif in generation 3 of 4
# Model Number: 454 with model SeasonalNaive in generation 3 of 4
# Model Number: 455 with model LastValueNaive in generation 3 of 4
# Model Number: 456 with model VECM in generation 3 of 4
# Model Number: 457 with model SeasonalityMotif in generation 3 of 4
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 457: SeasonalityMotif
# Model Number: 458 with model RRVAR in generation 3 of 4
# Model Number: 459 with model RRVAR in generation 3 of 4
# Model Number: 460 with model Cassandra in generation 3 of 4
# C:\Users\yensanwoo\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.92128e-26): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# Model Number: 461 with model ETS in generation 3 of 4
# New Generation: 4 of 4
# Model Number: 462 with model KalmanStateSpace in generation 4 of 4
# Model Number: 463 with model LastValueNaive in generation 4 of 4
# Model Number: 464 with model ConstantNaive in generation 4 of 4
# Template Eval Error: Exception('Transformer PowerTransformer failed on fit') in model 464: ConstantNaive
# Model Number: 465 with model LastValueNaive in generation 4 of 4
# Model Number: 466 with model RRVAR in generation 4 of 4
# Model Number: 467 with model SectionalMotif in generation 4 of 4
# Model Number: 468 with model MultivariateMotif in generation 4 of 4
# Model Number: 469 with model UnivariateMotif in generation 4 of 4
# Model Number: 470 with model VECM in generation 4 of 4
# Model Number: 471 with model VECM in generation 4 of 4
# Model Number: 472 with model SeasonalityMotif in generation 4 of 4
# Model Number: 473 with model WindowRegression in generation 4 of 4
# Model Number: 474 with model VAR in generation 4 of 4
# Model Number: 475 with model MultivariateMotif in generation 4 of 4
# Model Number: 476 with model NVAR in generation 4 of 4
# Template Eval Error: ValueError('Model NVAR returned NaN for one or more series. fail_on_forecast_nan=True') in model 476: NVAR
# Model Number: 477 with model SeasonalNaive in generation 4 of 4
# Model Number: 478 with model LastValueNaive in generation 4 of 4
# Model Number: 479 with model MultivariateMotif in generation 4 of 4
# Model Number: 480 with model SeasonalityMotif in generation 4 of 4
# Model Number: 481 with model Cassandra in generation 4 of 4
# Model Number: 482 with model VECM in generation 4 of 4
# Model Number: 483 with model ETS in generation 4 of 4
# Model Number: 484 with model ConstantNaive in generation 4 of 4
# Model Number: 485 with model MetricMotif in generation 4 of 4
# Model Number: 486 with model AverageValueNaive in generation 4 of 4
# Model Number: 487 with model RRVAR in generation 4 of 4
# Model Number: 488 with model MetricMotif in generation 4 of 4
# Template Eval Error: Exception('Transformer MinMaxScaler failed on fit') in model 488: MetricMotif
# Model Number: 489 with model RRVAR in generation 4 of 4
# Model Number: 490 with model SeasonalityMotif in generation 4 of 4
# Model Number: 491 with model MultivariateMotif in generation 4 of 4
# Model Number: 492 with model AverageValueNaive in generation 4 of 4
# Model Number: 493 with model VECM in generation 4 of 4
# Model Number: 494 with model WindowRegression in generation 4 of 4
# Model Number: 495 with model MetricMotif in generation 4 of 4
# C:\Users\yensanwoo\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Model Number: 496 with model MultivariateMotif in generation 4 of 4
# Model Number: 497 with model RRVAR in generation 4 of 4
# Model Number: 498 with model VECM in generation 4 of 4
# Model Number: 499 with model SectionalMotif in generation 4 of 4
# Model Number: 500 with model AverageValueNaive in generation 4 of 4
# Model Number: 501 with model ETS in generation 4 of 4
# Model Number: 502 with model RRVAR in generation 4 of 4
# Model Number: 503 with model SeasonalityMotif in generation 4 of 4
# Model Number: 504 with model Cassandra in generation 4 of 4
# Model Number: 505 with model AverageValueNaive in generation 4 of 4
# Model Number: 506 with model LastValueNaive in generation 4 of 4
# Model Number: 507 with model AverageValueNaive in generation 4 of 4
# Model Number: 508 with model MultivariateMotif in generation 4 of 4
# ...
# 35 - UnivariateMotif with avg smape 22.21:
# Model Number: 36 of 85 with model VECM for Validation 1
# 36 - VECM with avg smape 23.9:
# Model Number: 37 of 85 with model VECM for Validation 1
# 37 - VECM with avg smape 24.15:
# Model Number: 38 of 85 with model AverageValueNaive for Validation 1
# 38 - AverageValueNaive with avg smape 26.51:
# Model Number: 39 of 85 with model VECM for Validation 1
# 39 - VECM with avg smape 28.79:
# Model Number: 40 of 85 with model SeasonalityMotif for Validation 1
# 40 - SeasonalityMotif with avg smape 23.05:
# Model Number: 41 of 85 with model SectionalMotif for Validation 1
# 41 - SectionalMotif with avg smape 25.11:
# Model Number: 42 of 85 with model VECM for Validation 1
# 42 - VECM with avg smape 30.3:
# Model Number: 43 of 85 with model UnivariateMotif for Validation 1
# 43 - UnivariateMotif with avg smape 26.22:
# Model Number: 44 of 85 with model SeasonalityMotif for Validation 1
# 44 - SeasonalityMotif with avg smape 26.31:
# Model Number: 45 of 85 with model MetricMotif for Validation 1
# 45 - MetricMotif with avg smape 29.62:
# Model Number: 46 of 85 with model SeasonalityMotif for Validation 1
# 46 - SeasonalityMotif with avg smape 24.84:
# Model Number: 47 of 85 with model SectionalMotif for Validation 1
# 47 - SectionalMotif with avg smape 26.81:
# Model Number: 48 of 85 with model ETS for Validation 1
# C:\Users\yensanwoo\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.99117e-26): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# 48 - ETS with avg smape 22.81:
# Model Number: 49 of 85 with model SeasonalityMotif for Validation 1
# 49 - SeasonalityMotif with avg smape 24.73:
# Model Number: 50 of 85 with model ETS for Validation 1
# 50 - ETS with avg smape 25.19:
# Model Number: 51 of 85 with model ETS for Validation 1
# C:\Users\yensanwoo\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.99117e-26): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# 51 - ETS with avg smape 22.97:
# Model Number: 52 of 85 with model MetricMotif for Validation 1
# 52 - MetricMotif with avg smape 23.42:
# Model Number: 53 of 85 with model MetricMotif for Validation 1
# 53 - MetricMotif with avg smape 33.88:
# Model Number: 54 of 85 with model MetricMotif for Validation 1
# 54 - MetricMotif with avg smape 23.09:
# Model Number: 55 of 85 with model AverageValueNaive for Validation 1
# 55 - AverageValueNaive with avg smape 29.17:
# Model Number: 56 of 85 with model SectionalMotif for Validation 1
# 56 - SectionalMotif with avg smape 30.95:
# Model Number: 57 of 85 with model SectionalMotif for Validation 1
# 57 - SectionalMotif with avg smape 33.29:
# Model Number: 58 of 85 with model AverageValueNaive for Validation 1
# 58 - AverageValueNaive with avg smape 28.3:
# Model Number: 59 of 85 with model AverageValueNaive for Validation 1
# 59 - AverageValueNaive with avg smape 28.43:
# Model Number: 60 of 85 with model SectionalMotif for Validation 1
# 60 - SectionalMotif with avg smape 25.02:
# Model Number: 61 of 85 with model KalmanStateSpace for Validation 1
# 61 - KalmanStateSpace with avg smape 23.2:
# Model Number: 62 of 85 with model ETS for Validation 1
# 62 - ETS with avg smape 33.83:
# Model Number: 63 of 85 with model RRVAR for Validation 1
# 63 - RRVAR with avg smape 24.86:
# Model Number: 64 of 85 with model VAR for Validation 1
# 64 - VAR with avg smape 28.4:
# Model Number: 65 of 85 with model NVAR for Validation 1
# 65 - NVAR with avg smape 30.69:
# Model Number: 66 of 85 with model NVAR for Validation 1
# 66 - NVAR with avg smape 30.96:
# Model Number: 67 of 85 with model MAR for Validation 1
# 67 - MAR with avg smape 27.58:
# Model Number: 68 of 85 with model SeasonalNaive for Validation 1
# 68 - SeasonalNaive with avg smape 29.95:
# Model Number: 69 of 85 with model SeasonalNaive for Validation 1
# 69 - SeasonalNaive with avg smape 29.72:
# Model Number: 70 of 85 with model MetricMotif for Validation 1
# 70 - MetricMotif with avg smape 24.82:
# Model Number: 71 of 85 with model SeasonalNaive for Validation 1
# 71 - SeasonalNaive with avg smape 43.03:
# Model Number: 72 of 85 with model VAR for Validation 1
# 72 - VAR with avg smape 25.49:
# Model Number: 73 of 85 with model VAR for Validation 1
# 73 - VAR with avg smape 27.49:
# Model Number: 74 of 85 with model RRVAR for Validation 1
# 74 - RRVAR with avg smape 33.34:
# Model Number: 75 of 85 with model RRVAR for Validation 1
# 75 - RRVAR with avg smape 33.34:
# Model Number: 76 of 85 with model RRVAR for Validation 1
# 76 - RRVAR with avg smape 33.34:
# Model Number: 77 of 85 with model SeasonalNaive for Validation 1
# 77 - SeasonalNaive with avg smape 25.23:
# Model Number: 78 of 85 with model WindowRegression for Validation 1
# 78 - WindowRegression with avg smape 25.62:
# Model Number: 79 of 85 with model VAR for Validation 1
# C:\Users\yensanwoo\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 79 - VAR with avg smape 22.84:
# Model Number: 80 of 85 with model VAR for Validation 1
# 80 - VAR with avg smape 27.12:
# Model Number: 81 of 85 with model RRVAR for Validation 1
# 81 - RRVAR with avg smape 29.74:
# Model Number: 82 of 85 with model RRVAR for Validation 1
# 82 - RRVAR with avg smape 33.83:
# Model Number: 83 of 85 with model ConstantNaive for Validation 1
# 83 - ConstantNaive with avg smape 26.51:
# Model Number: 84 of 85 with model GLS for Validation 1
# 84 - GLS with avg smape 24.09:
# Model Number: 85 of 85 with model ConstantNaive for Validation 1
# 85 - ConstantNaive with avg smape 33.04:
# Validation Round: 2
# Model Number: 1 of 85 with model Cassandra for Validation 2
# 📈 1 - Cassandra with avg smape 24.78:
# Model Number: 2 of 85 with model AverageValueNaive for Validation 2
# 📈 2 - AverageValueNaive with avg smape 15.49:
# Model Number: 3 of 85 with model Cassandra for Validation 2
# 3 - Cassandra with avg smape 34.02:
# Model Number: 4 of 85 with model Cassandra for Validation 2
# 4 - Cassandra with avg smape 25.44:
# Model Number: 5 of 85 with model MultivariateMotif for Validation 2
# 5 - MultivariateMotif with avg smape 16.61:
# Model Number: 6 of 85 with model MultivariateMotif for Validation 2
# 📈 6 - MultivariateMotif with avg smape 14.19:
# Model Number: 7 of 85 with model AverageValueNaive for Validation 2
# 7 - AverageValueNaive with avg smape 16.0:
# Model Number: 8 of 85 with model UnivariateMotif for Validation 2
# 8 - UnivariateMotif with avg smape 15.08:
# Model Number: 9 of 85 with model LastValueNaive for Validation 2
# 9 - LastValueNaive with avg smape 19.36:
# Model Number: 10 of 85 with model SeasonalityMotif for Validation 2
# 10 - SeasonalityMotif with avg smape 18.24:
# Model Number: 11 of 85 with model ETS for Validation 2
# 11 - ETS with avg smape 20.84:
# Model Number: 12 of 85 with model UnivariateMotif for Validation 2
# 12 - UnivariateMotif with avg smape 15.83:
# Model Number: 13 of 85 with model Cassandra for Validation 2
# 13 - Cassandra with avg smape 19.06:
# Model Number: 14 of 85 with model Cassandra for Validation 2
# 14 - Cassandra with avg smape 19.59:
# Model Number: 15 of 85 with model Cassandra for Validation 2
# 15 - Cassandra with avg smape 20.81:
# Model Number: 16 of 85 with model MultivariateMotif for Validation 2
# 16 - MultivariateMotif with avg smape 16.69:
# Model Number: 17 of 85 with model MultivariateMotif for Validation 2
# 17 - MultivariateMotif with avg smape 16.69:
# Model Number: 18 of 85 with model LastValueNaive for Validation 2
# 18 - LastValueNaive with avg smape 19.03:
# Model Number: 19 of 85 with model MetricMotif for Validation 2
# 19 - MetricMotif with avg smape 18.73:
# Model Number: 20 of 85 with model LastValueNaive for Validation 2
# 20 - LastValueNaive with avg smape 19.38:
# Model Number: 21 of 85 with model VECM for Validation 2
# 21 - VECM with avg smape 16.25:
# Model Number: 22 of 85 with model MultivariateMotif for Validation 2
# 22 - MultivariateMotif with avg smape 17.28:
# Model Number: 23 of 85 with model MultivariateMotif for Validation 2
# 23 - MultivariateMotif with avg smape 17.85:
# Model Number: 24 of 85 with model UnivariateMotif for Validation 2
# 24 - UnivariateMotif with avg smape 14.73:
# Model Number: 25 of 85 with model SeasonalNaive for Validation 2
# 25 - SeasonalNaive with avg smape 19.29:
# Model Number: 26 of 85 with model SeasonalNaive for Validation 2
# 26 - SeasonalNaive with avg smape 19.34:
# Model Number: 27 of 85 with model LastValueNaive for Validation 2
# 27 - LastValueNaive with avg smape 18.23:
# Model Number: 28 of 85 with model LastValueNaive for Validation 2
# 28 - LastValueNaive with avg smape 19.03:
# Model Number: 29 of 85 with model LastValueNaive for Validation 2
# 29 - LastValueNaive with avg smape 18.38:
# Model Number: 30 of 85 with model ETS for Validation 2
# 30 - ETS with avg smape 25.22:
# Model Number: 31 of 85 with model SectionalMotif for Validation 2
# 31 - SectionalMotif with avg smape 15.01:
# Model Number: 32 of 85 with model VECM for Validation 2
# 32 - VECM with avg smape 15.3:
# Model Number: 33 of 85 with model UnivariateMotif for Validation 2
# 33 - UnivariateMotif with avg smape 19.81:
# Model Number: 34 of 85 with model SeasonalityMotif for Validation 2
# 34 - SeasonalityMotif with avg smape 16.59:
# Model Number: 35 of 85 with model UnivariateMotif for Validation 2
# 35 - UnivariateMotif with avg smape 18.47:
# Model Number: 36 of 85 with model VECM for Validation 2
# 📈 36 - VECM with avg smape 13.37:
# Model Number: 37 of 85 with model VECM for Validation 2
# 37 - VECM with avg smape 13.4:
# Model Number: 38 of 85 with model AverageValueNaive for Validation 2
# 38 - AverageValueNaive with avg smape 19.27:
# Model Number: 39 of 85 with model VECM for Validation 2
# 39 - VECM with avg smape 22.32:
# Model Number: 40 of 85 with model SeasonalityMotif for Validation 2
# 40 - SeasonalityMotif with avg smape 15.0:
# Model Number: 41 of 85 with model SectionalMotif for Validation 2
# 41 - SectionalMotif with avg smape 27.61:
# Model Number: 42 of 85 with model VECM for Validation 2
# 42 - VECM with avg smape 24.87:
# Model Number: 43 of 85 with model UnivariateMotif for Validation 2
# 43 - UnivariateMotif with avg smape 17.65:
# Model Number: 44 of 85 with model SeasonalityMotif for Validation 2
# 44 - SeasonalityMotif with avg smape 16.71:
# Model Number: 45 of 85 with model MetricMotif for Validation 2
# 45 - MetricMotif with avg smape 25.41:
# Model Number: 46 of 85 with model SeasonalityMotif for Validation 2
# 46 - SeasonalityMotif with avg smape 16.03:
# Model Number: 47 of 85 with model SectionalMotif for Validation 2
# 47 - SectionalMotif with avg smape 19.91:
# Model Number: 48 of 85 with model ETS for Validation 2
# C:\Users\yensanwoo\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.06253e-26): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# 📈 48 - ETS with avg smape 12.98:
# Model Number: 49 of 85 with model SeasonalityMotif for Validation 2
# 49 - SeasonalityMotif with avg smape 15.31:
# Model Number: 50 of 85 with model ETS for Validation 2
# 50 - ETS with avg smape 16.35:
# Model Number: 51 of 85 with model ETS for Validation 2
# C:\Users\yensanwoo\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.06253e-26): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# 51 - ETS with avg smape 14.13:
# Model Number: 52 of 85 with model MetricMotif for Validation 2
# 52 - MetricMotif with avg smape 19.01:
# Model Number: 53 of 85 with model MetricMotif for Validation 2
# 53 - MetricMotif with avg smape 26.14:
# Model Number: 54 of 85 with model MetricMotif for Validation 2
# 54 - MetricMotif with avg smape 18.09:
# Model Number: 55 of 85 with model AverageValueNaive for Validation 2
# 55 - AverageValueNaive with avg smape 20.34:
# Model Number: 56 of 85 with model SectionalMotif for Validation 2
# 56 - SectionalMotif with avg smape 26.16:
# Model Number: 57 of 85 with model SectionalMotif for Validation 2
# 57 - SectionalMotif with avg smape 25.16:
# Model Number: 58 of 85 with model AverageValueNaive for Validation 2
# 58 - AverageValueNaive with avg smape 18.13:
# Model Number: 59 of 85 with model AverageValueNaive for Validation 2
# 59 - AverageValueNaive with avg smape 18.26:
# Model Number: 60 of 85 with model SectionalMotif for Validation 2
# 60 - SectionalMotif with avg smape 19.06:
# Model Number: 61 of 85 with model KalmanStateSpace for Validation 2
# 61 - KalmanStateSpace with avg smape 15.52:
# Model Number: 62 of 85 with model ETS for Validation 2
# 62 - ETS with avg smape 21.76:
# Model Number: 63 of 85 with model RRVAR for Validation 2
# 63 - RRVAR with avg smape 16.85:
# Model Number: 64 of 85 with model VAR for Validation 2
# 64 - VAR with avg smape 20.94:
# Model Number: 65 of 85 with model NVAR for Validation 2
# 65 - NVAR with avg smape 23.82:
# Model Number: 66 of 85 with model NVAR for Validation 2
# 66 - NVAR with avg smape 23.16:
# Model Number: 67 of 85 with model MAR for Validation 2
# 67 - MAR with avg smape 17.72:
# Model Number: 68 of 85 with model SeasonalNaive for Validation 2
# 68 - SeasonalNaive with avg smape 25.98:
# Model Number: 69 of 85 with model SeasonalNaive for Validation 2
# 69 - SeasonalNaive with avg smape 24.98:
# Model Number: 70 of 85 with model MetricMotif for Validation 2
# 70 - MetricMotif with avg smape 15.88:
# Model Number: 71 of 85 with model SeasonalNaive for Validation 2
# 71 - SeasonalNaive with avg smape 27.86:
# Model Number: 72 of 85 with model VAR for Validation 2
# 72 - VAR with avg smape 17.34:
# Model Number: 73 of 85 with model VAR for Validation 2
# 73 - VAR with avg smape 16.57:
# Model Number: 74 of 85 with model RRVAR for Validation 2
# 74 - RRVAR with avg smape 31.56:
# Model Number: 75 of 85 with model RRVAR for Validation 2
# 75 - RRVAR with avg smape 31.56:
# Model Number: 76 of 85 with model RRVAR for Validation 2
# 76 - RRVAR with avg smape 31.56:
# Model Number: 77 of 85 with model SeasonalNaive for Validation 2
# 77 - SeasonalNaive with avg smape 15.48:
# Model Number: 78 of 85 with model WindowRegression for Validation 2
# C:\Users\yensanwoo\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 78 - WindowRegression with avg smape 17.47:
# Model Number: 79 of 85 with model VAR for Validation 2
# 79 - VAR with avg smape 16.1:
# Model Number: 80 of 85 with model VAR for Validation 2
# 80 - VAR with avg smape 17.93:
# Model Number: 81 of 85 with model RRVAR for Validation 2
# 81 - RRVAR with avg smape 26.3:
# Model Number: 82 of 85 with model RRVAR for Validation 2
# 82 - RRVAR with avg smape 32.44:
# Model Number: 83 of 85 with model ConstantNaive for Validation 2
# 83 - ConstantNaive with avg smape 19.34:
# Model Number: 84 of 85 with model GLS for Validation 2
# 84 - GLS with avg smape 23.24:
# Model Number: 85 of 85 with model ConstantNaive for Validation 2
# 85 - ConstantNaive with avg smape 29.32:
# Initiated AutoTS object with best model:
# MultivariateMotif
# {'fillna': 'ffill', 'transformations': {'0': 'StandardScaler'}, 'transformation_params': {'0': {}}}
# {'window': 10, 'point_method': 'midhinge', 'distance_metric': 'sqeuclidean', 'k': 10, 'max_windows': 10000}
# SMAPE: 21.54225747684497, 20.65500679306499, 14.189016175712904
# MAE: 1310214.310040397, 1422110.2732861966, 809606.494011751
# SPL: 1.468000383374419, 6.912640735706263, 0.9554192387679618
